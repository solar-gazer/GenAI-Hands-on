# %% [markdown]
# ---

# %% [markdown]
# # Unit 2 - Part 2a: The Anatomy of a Prompt
#
# ## 1. Introduction: Stochasticity (Randomness)
#
# Why does the AI give different answers? Because it is **Stochastic** (Random).
#
# It predicts the NEXT TOKEN based on probability.
#
# ### Visualizing the Prediction
# Input: `"The sky is..."`
#
# | Word | Probability | Selected? (Temp=0) | Selected? (Temp=1) |
# |------|-------------|--------------------|--------------------|
# | Blue | 80% | ✅ | ❌ |
# | Gray | 15% | ❌ | ✅ |
# | Green| 1% | ❌ | ❌ |
#
# Prompt Engineering is the art of **manipulating these probabilities**.

# %%
# Setup
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

# Using Low Temp for consistent comparison
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)

# %% [markdown]
# ## 2. The CO-STAR Framework (simplified)
#
# A good prompt usually has:
# 1.  **C**ontext (Who are you? Who acts?)
# 2.  **O**bjective (What is the task?)
# 3.  **S**tyle (Formal? Funny?)
# 4.  **T**one (Empathetic? Direct?)
# 5.  **A**udience (Who is reading this?)
# 6.  **R**esponse Format (JSON? List?)
#
# Let's compare a **Lazy Prompt** vs a **CO-STAR Prompt**.

# %%
# The Task: Reject a candidate for a job.
task = "Write a rejection email to a candidate."

print("--- LAZY PROMPT ---")
print(llm.invoke(task).content)
# Out:
# --- LAZY PROMPT ---
# Writing a rejection email is never easy, but it's crucial to be professional, polite, and clear. Here are a few options, ranging from a general rejection after an application to one after an interview, along with some tips.
#
# ---
#
# **General Tips for Rejection Emails:**
#
# 1.  **Be Timely:** Send it as soon as a decision is made.
# 2.  **Be Clear and Direct:** Don't beat around the bush, but be polite.
# 3.  **Be Professional:** Maintain a positive image for your company.
# 4.  **Avoid Specific Feedback:** Do not give detailed reasons for rejection (e.g., "you lacked X skill," "your personality wasn't a fit"). This can open the door to debate, legal issues, or make the candidate feel worse. Stick to general statements like "we've decided to move forward with other candidates whose qualifications were a closer match."
# 5.  **Thank Them:** Always thank them for their time and interest.
# 6.  **Proofread:** Ensure there are no typos or grammatical errors.
#
# ---
#
# **Option 1: After Application/Resume Review (No Interview)**
#
# **Subject: Update on Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your interest in the [Job Title] position at [Company Name] and for submitting your application.
#
# We received a large number of applications for this role, and after careful consideration, we have decided to move forward with other candidates whose qualifications and experience were a closer match for the specific requirements of this position at this time.
#
# We appreciate you taking the time to apply and wish you the best of luck in your job search and future endeavors.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Company Website (Optional)]
#
# ---
#
# **Option 2: After an Interview (More Personal)**
#
# **Subject: Regarding Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your interest in the [Job Title] position at [Company Name] and for taking the time to interview with our team. We truly enjoyed learning more about your background and experience.
#
# We had many qualified applicants, and this was a highly competitive search. While your qualifications are impressive, we have decided to move forward with other candidates whose experience and qualifications were a stronger fit for the specific requirements of this role at this time.
#
# We appreciate you sharing your time and insights with us and wish you the very best in your job search and future career.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Company Website (Optional)]
#
# ---
#
# **Option 3: Slightly Softer Tone (Can be used after application or interview)**
#
# **Subject: Update on Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your application for the [Job Title] position at [Company Name]. We appreciate you taking the time to share your qualifications with us [and for interviewing with our team, if applicable].
#
# We received a significant number of applications from highly qualified individuals, making our decision a difficult one. After careful consideration, we have decided to pursue other candidates whose profiles were a slightly closer match for the specific needs of this role.
#
# We wish you all the best in your job search and future professional endeavors.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Company Name]
# [Company Website (Optional)]
#
# ---
#
# **Choose the option that best fits your company's tone and the stage of the hiring process.** Remember, a polite and professional rejection can leave a positive impression, even if the news isn't what the candidate hoped for.

# %% [markdown]
# ## 3. Hallucination vs. Creativity
#
# Did the model make up a reason?
# Since we didn't give it facts, it **Predicted the most likely reason** (Usually "Experience" or "Volume of applications").
#
# **This is NOT a bug.** It is a feature. The model is *completing the pattern* of a rejection email.

# %%
structured_prompt = """
# Context
You are an HR Manager at a quirky startup called 'RocketBoots'.

# Objective
Write a rejection email to a candidate named Bob.

# Constraints
1. Be extremely brief (under 50 words).
2. Do NOT say 'we found someone better'. Say 'the role changed'.
3. Sign off with 'Keep flying'.

# Output Format
Plain text, no subject line.
"""

print("--- STRUCTURED PROMPT ---")
print(llm.invoke(structured_prompt).content)
# Out:
# --- STRUCTURED PROMPT ---
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:6021, in Models.generate_content(self, model, contents, config)
#    6020 i += 1
# -> 6021 response = self._generate_content(
#    6022     model=model, contents=contents, config=parsed_config
#    6023 )
#    6025 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:4683, in Models._generate_content(self, model, contents, config)
#    4681 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4683 response = self._api_client.request(
#    4684     'post', path, request_dict, http_options
#    4685 )
#    4687 if config is not None and getattr(
#    4688     config, 'should_return_http_response', None
#    4689 ):
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1532, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1529 http_request = self._build_request(
#    1530     http_method, path, request_dict, http_options
#    1531 )
# -> 1532 response = self._request(http_request, http_options, stream=False)
#    1533 response_body = (
#    1534     response.response_stream[0] if response.response_stream else ''
#    1535 )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1325, in BaseApiClient._request(self, http_request, http_options, stream)
#    1324     retry = tenacity.Retrying(**retry_kwargs)
# -> 1325     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1327 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1304, in BaseApiClient._request_once(self, http_request, stream)
#    1303   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1304 errors.APIError.raise_for_response(response)
#    1305 return HttpResponse(
#    1306     response.headers, response if stream else [response.text]
#    1307 )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 55.837535419s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[3], line 18
#       1 structured_prompt = """
#       2 # Context
#       3 You are an HR Manager at a quirky startup called 'RocketBoots'.
#    (...)     14 Plain text, no subject line.
#      15 """
#      17 print("--- STRUCTURED PROMPT ---")
# ---> 18 print(llm.invoke(structured_prompt).content)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 55.837535419s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '55s'}]}}

# %% [markdown]
# ## 4. Key Takeaway: Ambiguity is the Enemy
#
# Every piece of information you leave out is a gap the model MUST fill with probability.
# - If you don't say "Be brief", it picks the most probable length (Avg email length).
# - If you don't say "Be rude", it picks the most probable tone (Polite/Neutral).

# %% [markdown]
# ## Assignment
#
# Write a structured prompt to generate a **Python Function**.
# - **Context:** You are a Senior Python Dev.
# - **Objective:** Write a function to reverse a string.
# - **Constraint:** It must use recursion (no slicing `[::-1]`).
# - **Style:** Include detailed docstrings.

# %% [markdown]
# ---

# %% [markdown]
# # Unit 2 - Part 2b: Zero-Shot to Few-Shot
#
# ## 1. Introduction: In-Context Learning
#
# How does the model learn without training?
# This is called **In-Context Learning**.
#
# ### The Attention Mechanism (Flowchart)
# When you ask a question, the model "looks back" at the previous text to find patterns.
#
# ```mermaid
# graph TD
#     Input[Current Input: 'Angry + Hungry'] -->|Attention Query| History
#     subgraph History [The Prompt Examples]
#         Ex1[Ex1: Breakfast + Lunch = Brunch]
#         Ex2[Ex2: Chill + Relax = Chillax]
#     end
#     History -->|Pattern Found: Mix words & define| Prediction[Output: Hangry]
# ```

# %%
# Setup
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.5)

# %% [markdown]
# ## 2. Zero-Shot (No Context)
#
# The model relies purely on its training data.

# %%
prompt_zero = "Combine 'Angry' and 'Hungry' into a funny new word."
print(f"Zero-Shot: {llm.invoke(prompt_zero).content}")
# Out:
# Zero-Shot: The most common and widely accepted funny word for this is:
#
# **Hangry**
#
# It perfectly combines the "H" from Hungry with the "angry" sound, describing the state of being irritable due to hunger.

# %% [markdown]
# ## 3. Few-Shot (Pattern Matching)
#
# We provide examples. The Attention Mechanism attends to the **Structure** (`Input -> Output`) and the **Tone** (Sarcasm).

# %%
prompt_few = """
Combine words into a funny new word. Give a sarcastic definition.

Input: Breakfast + Lunch
Output: Brunch (An excuse to drink alcohol before noon)

Input: Chill + Relax
Output: Chillax (What annoying people say when you are panic attacks)

Input: Angry + Hungry
Output:
"""
print(f"Few-Shot: {llm.invoke(prompt_few).content}")
# Out:
# Few-Shot: Output: Hangry (A completely valid medical condition that justifies all your terrible behavior until someone shoves a snack in your face.)

# %% [markdown]
# ## 4. Critical Analysis
#
# If you provide **bad examples**, the model will learn the **bad pattern**.
# This is why Data Quality in your prompt is just as important as code quality.

# %% [markdown]
# ---

# %% [markdown]
# # Unit 2 - Part 2c: Advanced Templates & Theory
#
# ## 1. Theory: Engineering vs. Training
#
# ### Hard Prompts (Prompt Engineering)
# - **What:** You change the text input.
# - **Cost:** Cheap, fast, easy to iterate.
# - **Use Case:** Prototyping, General tasks.
#
# ### Soft Prompts (Fine Tuning)
# - **What:** You change the model's internal weights (mathematically).
# - **Cost:** Expensive, slow, needs data.
# - **Use Case:** Domain specificity (Medical, Legal), Behavioral change.

# %%
# Setup
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %% [markdown]
# ## 2. Dynamic Few-Shotting
#
# If you have 1000 examples, you can't fit them all in the context window.
# We use a **Selector** to pick the best ones.
#
# ### The Selector Flow (Flowchart)
# ```mermaid
# graph LR
#     Input[User Input] -->|Semantic Search| Database[Example Database]
#     Database -->|Top 3 Matches| Selector
#     Selector -->|Inject| Prompt
# ```

# %%
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate

# 1. Our Database of Examples
examples = [
    {"input": "The internet is down.", "output": "We are observing connectivity latency."}, 
    {"input": "This code implies a bug.", "output": "The logic suggests unintended behavior."}, 
    {"input": "I hate this feature.", "output": "This feature does not align with my preferences."}, 
]

# 2. Template for ONE example
example_fmt = ChatPromptTemplate.from_messages([
    ("human", "{input}"),
    ("ai", "{output}")
])

# 3. The Few-Shot Container
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_fmt,
    examples=examples
)

# 4. The Final Chain
final_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a Corpo-Speak Translator. Rewrite the input to sound professional."),
    few_shot_prompt,      # Inject examples here
    ("human", "{text}")
])

chain = final_prompt | llm

print(chain.invoke({"text": "This app sucks."}).content)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:6021, in Models.generate_content(self, model, contents, config)
#    6020 i += 1
# -> 6021 response = self._generate_content(
#    6022     model=model, contents=contents, config=parsed_config
#    6023 )
#    6025 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:4683, in Models._generate_content(self, model, contents, config)
#    4681 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4683 response = self._api_client.request(
#    4684     'post', path, request_dict, http_options
#    4685 )
#    4687 if config is not None and getattr(
#    4688     config, 'should_return_http_response', None
#    4689 ):
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1532, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1529 http_request = self._build_request(
#    1530     http_method, path, request_dict, http_options
#    1531 )
# -> 1532 response = self._request(http_request, http_options, stream=False)
#    1533 response_body = (
#    1534     response.response_stream[0] if response.response_stream else ''
#    1535 )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1325, in BaseApiClient._request(self, http_request, http_options, stream)
#    1324     retry = tenacity.Retrying(**retry_kwargs)
# -> 1325     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1327 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1304, in BaseApiClient._request_once(self, http_request, stream)
#    1303   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1304 errors.APIError.raise_for_response(response)
#    1305 return HttpResponse(
#    1306     response.headers, response if stream else [response.text]
#    1307 )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 8.708742432s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '8s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[8], line 31
#      23 final_prompt = ChatPromptTemplate.from_messages([
#      24     ("system", "You are a Corpo-Speak Translator. Rewrite the input to sound professional."),
#      25     few_shot_prompt,      # Inject examples here
#      26     ("human", "{text}")
#      27 ])
#      29 chain = final_prompt | llm
# ---> 31 print(chain.invoke({"text": "This app sucks."}).content)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:2535, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2532         msg = "Tools are already defined.code_execution tool can't be defined"
#    2533         raise ValueError(msg)
# -> 2535 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:454, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     440 @override
#     441 def invoke(
#     442     self,
#    (...)    447     **kwargs: Any,
#     448 ) -> AIMessage:
#     449     config = ensure_config(config)
#     450     return cast(
#     451         "AIMessage",
#     452         cast(
#     453             "ChatGeneration",
# --> 454             self.generate_prompt(
#     455                 [self._convert_input(input)],
#     456                 stop=stop,
#     457                 callbacks=config.get("callbacks"),
#     458                 tags=config.get("tags"),
#     459                 metadata=config.get("metadata"),
#     460                 run_name=config.get("run_name"),
#     461                 run_id=config.pop("run_id", None),
#     462                 **kwargs,
#     463             ).generations[0][0],
#     464         ).message,
#     465     )
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1185, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1176 @override
#    1177 def generate_prompt(
#    1178     self,
#    (...)   1182     **kwargs: Any,
#    1183 ) -> LLMResult:
#    1184     prompt_messages = [p.to_messages() for p in prompts]
# -> 1185     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:995, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     992 for i, m in enumerate(input_messages):
#     993     try:
#     994         results.append(
# --> 995             self._generate_with_cache(
#     996                 m,
#     997                 stop=stop,
#     998                 run_manager=run_managers[i] if run_managers else None,
#     999                 **kwargs,
#    1000             )
#    1001         )
#    1002     except BaseException as e:
#    1003         if run_managers:
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1297, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295     result = generate_from_stream(iter(chunks))
#    1296 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297     result = self._generate(
#    1298         messages, stop=stop, run_manager=run_manager, **kwargs
#    1299     )
#    1300 else:
#    1301     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:3051, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
# -> 3051     _handle_client_error(e, request)
#    3053 return _response_to_result(response)
#
# File c:\Users\Aadarsh Koushik\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 8.708742432s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '8s'}]}}

# %% [markdown]
# ## 3. Analysis
#
# Using `FewShotChatMessagePromptTemplate` creates a clean separation between instructions and data. This helps the Attention Mechanism focus on the right things.
